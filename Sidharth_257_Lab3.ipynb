# %% [markdown]
# <a href="https://colab.research.google.com/github/sidhugitacc/Advanced-python/blob/main/Sidharth_257_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## LAB 3

# %% [markdown]
# ### 1. Data Preprocessing:

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Load the CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Data Preprocessing
# Normalize pixel values to between 0 and 1
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# One-hot encode class labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 293s 2us/step

# %% [markdown]
# ### 2. Network Architecture Design:

# %%
# Define the model architecture
model = models.Sequential()

# Input Layer
model.add(layers.InputLayer(input_shape=(32, 32, 3)))

# Hidden Layer 1: Convolutional + ReLU Activation + MaxPooling
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))

# Hidden Layer 2: Convolutional + ReLU Activation + MaxPooling
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))

# Hidden Layer 3: Convolutional + ReLU Activation + MaxPooling
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten the output and add Fully Connected Layers
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))

# Output Layer: 10 classes with Softmax Activation
model.add(layers.Dense(10, activation='softmax'))
# Out:
# c:\Users\prana\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# ### 3. Training the Model:

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 651,978 (2.49 MB)
#  Trainable params: 651,978 (2.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 4. Train The model

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=64,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.3610 - loss: 1.7271 - val_accuracy: 0.5885 - val_loss: 1.1412
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.6259 - loss: 1.0560 - val_accuracy: 0.6754 - val_loss: 0.9359
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.7076 - loss: 0.8282 - val_accuracy: 0.7114 - val_loss: 0.8308
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7602 - loss: 0.6884 - val_accuracy: 0.7131 - val_loss: 0.8549
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 57ms/step - accuracy: 0.7996 - loss: 0.5752 - val_accuracy: 0.7393 - val_loss: 0.7818
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8302 - loss: 0.4828 - val_accuracy: 0.7371 - val_loss: 0.7852
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8611 - loss: 0.3945 - val_accuracy: 0.7496 - val_loss: 0.7816
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8842 - loss: 0.3263 - val_accuracy: 0.7546 - val_loss: 0.8428
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.9126 - loss: 0.2502 - val_accuracy: 0.7487 - val_loss: 0.9014
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9295 - loss: 0.2013 - val_accuracy: 0.7418 - val_loss: 1.0321
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9407 - loss: 0.1686 - val_accuracy: 0.7462 - val_loss: 1.0805
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9532 - loss: 0.1356 - val_accuracy: 0.7442 - val_loss: 1.1493
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9577 - loss: 0.1227 - val_accuracy: 0.7447 - val_loss: 1.3279
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9611 - loss: 0.1110 - val_accuracy: 0.7299 - val_loss: 1.3804
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 57ms/step - accuracy: 0.9641 - loss: 0.1021 - val_accuracy: 0.7362 - val_loss: 1.4615
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9664 - loss: 0.0946 - val_accuracy: 0.7489 - val_loss: 1.4431
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9687 - loss: 0.0871 - val_accuracy: 0.7308 - val_loss: 1.4814
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9722 - loss: 0.0798 - val_accuracy: 0.7388 - val_loss: 1.4970
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9712 - loss: 0.0840 - val_accuracy: 0.7402 - val_loss: 1.5885
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9742 - loss: 0.0775 - val_accuracy: 0.7370 - val_loss: 1.7186
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9739 - loss: 0.0792 - val_accuracy: 0.7342 - val_loss: 1.6462
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9775 - loss: 0.0647 - val_accuracy: 0.7334 - val_loss: 1.6498
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.9790 - loss: 0.0604 - val_accuracy: 0.7295 - val_loss: 1.7592
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9768 - loss: 0.0686 - val_accuracy: 0.7353 - val_loss: 1.7200
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9780 - loss: 0.0650 - val_accuracy: 0.7369 - val_loss: 1.8627
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.9777 - loss: 0.0653 - val_accuracy: 0.7354 - val_loss: 1.8273
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 46s 58ms/step - accuracy: 0.9785 - loss: 0.0642 - val_accuracy: 0.7324 - val_loss: 1.7325
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9798 - loss: 0.0580 - val_accuracy: 0.7402 - val_loss: 1.8085
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9854 - loss: 0.0470 - val_accuracy: 0.7383 - val_loss: 1.8304
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9815 - loss: 0.0574 - val_accuracy: 0.7397 - val_loss: 1.8970
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9852 - loss: 0.0463 - val_accuracy: 0.7325 - val_loss: 1.9208
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9803 - loss: 0.0606 - val_accuracy: 0.7249 - val_loss: 2.0754
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9810 - loss: 0.0562 - val_accuracy: 0.7394 - val_loss: 1.8778
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9835 - loss: 0.0482 - val_accuracy: 0.7378 - val_loss: 1.8943
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9838 - loss: 0.0496 - val_accuracy: 0.7232 - val_loss: 1.9823
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9831 - loss: 0.0507 - val_accuracy: 0.7396 - val_loss: 1.8595
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9875 - loss: 0.0356 - val_accuracy: 0.7367 - val_loss: 2.1080
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9855 - loss: 0.0462 - val_accuracy: 0.7266 - val_loss: 2.0507
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.9813 - loss: 0.0582 - val_accuracy: 0.7367 - val_loss: 1.9924
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.9858 - loss: 0.0423 - val_accuracy: 0.7315 - val_loss: 2.0736
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9836 - loss: 0.0508 - val_accuracy: 0.7293 - val_loss: 2.0845
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9825 - loss: 0.0564 - val_accuracy: 0.7314 - val_loss: 2.1510
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9874 - loss: 0.0410 - val_accuracy: 0.7320 - val_loss: 2.1540
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9879 - loss: 0.0414 - val_accuracy: 0.7439 - val_loss: 2.1324
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9859 - loss: 0.0426 - val_accuracy: 0.7413 - val_loss: 2.0795
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9861 - loss: 0.0437 - val_accuracy: 0.7395 - val_loss: 2.1323
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9841 - loss: 0.0492 - val_accuracy: 0.7368 - val_loss: 2.1509
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9875 - loss: 0.0376 - val_accuracy: 0.7412 - val_loss: 2.2083
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.9881 - loss: 0.0367 - val_accuracy: 0.7255 - val_loss: 2.2893
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9848 - loss: 0.0482 - val_accuracy: 0.7438 - val_loss: 2.1432

# %% [markdown]
# ### 5. Evaluate the model

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7473 - loss: 2.0861
#
# Test Accuracy: 0.7437999844551086

# %% [markdown]
# ### 6.Vizualize

# %%
# Plot accuracy and loss over epochs
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 6. Model Evaluation

# %%
# Generate predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Generate classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80      1000
#            1       0.89      0.83      0.86      1000
#            2       0.67      0.66      0.67      1000
#            3       0.57      0.48      0.52      1000
#            4       0.66      0.72      0.69      1000
#            5       0.63      0.67      0.65      1000
#            6       0.77      0.84      0.80      1000
#            7       0.78      0.78      0.78      1000
#            8       0.86      0.83      0.84      1000
#            9       0.82      0.82      0.82      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.74      0.74      0.74     10000
# weighted avg       0.74      0.74      0.74     10000

# %% [markdown]
# ### 7. Confusion Matrix

# %%
# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # CIFAR-10 Image Classification Using Neural Networks and Backpropagation
#
# In this project, we implemented a neural network to classify the images from the CIFAR-10 dataset. The CIFAR-10 dataset consists of 60,000 color images of size 32x32 pixels, divided into 10 classes (airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks). The goal is to classify these images using a feedforward neural network and backpropagation.
#
# ## Step-by-Step Explanation
#
# ### 1. Data Preprocessing
#
# We loaded the CIFAR-10 dataset using TensorFlow/Keras's `datasets` module and performed the following preprocessing steps:
# - **Normalization:** Pixel values were scaled to the range [0, 1] to make the data easier for the network to process.
# - **One-Hot Encoding:** The class labels were converted into one-hot encoded format since this is a multi-class classification problem.
# - **Data Splitting:** The dataset was split into a training set (50,000 images) and a test set (10,000 images). This split ensures that the model generalizes well to unseen data.
#
# ### 2. Network Architecture Design
#
# We designed a convolutional neural network (CNN) with the following layers:
# - **Input Layer:** The input shape is (32, 32, 3) since CIFAR-10 images have 32x32 pixels with 3 color channels (RGB).
# - **Convolutional Layers:** These layers extract local features from the images. We used 3 convolutional layers with filters of size 32, 64, and 64 respectively, and a kernel size of (3,3).
# - **Pooling Layers:** Max-pooling layers are added to reduce the spatial dimensions, thus down-sampling the feature maps and reducing computational complexity.
# - **Flatten Layer:** This layer flattens the 3D feature maps into 1D vectors, preparing the data for the fully connected layers.
# - **Fully Connected (Dense) Layers:** We used two dense layers—one hidden layer with 64 neurons and an output layer with 10 neurons (one for each class). The final output layer uses the **softmax** activation function for multi-class classification.
#
# ### 3. Activation Functions
#
# - We used the **ReLU (Rectified Linear Unit)** activation function for the hidden layers. ReLU introduces non-linearity into the model and is computationally efficient, making it a popular choice in deep learning models.
# - The **softmax** activation function was applied in the output layer, as it converts the raw output scores into class probabilities.
#
# ### 4. Loss Function and Optimizer
#
# - We selected **categorical cross-entropy** as the loss function, which is widely used in multi-class classification problems. This loss function measures the dissimilarity between the true labels and the predicted probabilities.
# - For optimization, we chose the **Adam** optimizer. Adam is an adaptive learning rate optimization algorithm that combines the advantages of both RMSprop and SGD, and it converges faster in practice.
# - The learning rate is a crucial hyperparameter that controls how much the model updates its weights during training. A learning rate that's too high can cause the model to overshoot the optimal solution, while a rate that's too low may slow down the convergence.
#
# ### 5. Model Training
#
# We trained the model for 50 epochs using backpropagation to update the weights. Backpropagation calculates the gradients of the loss with respect to each weight in the network and updates the weights using the optimizer’s rules.
#
# During training, both the training and validation accuracies were monitored to track the model’s performance and avoid overfitting. Early stopping or adjusting learning rates can prevent overfitting and lead to smoother convergence.
#
# ### 6. Model Evaluation
#
# After training, the model was evaluated on the test set. The following metrics were used to assess the model's performance:
# - **Accuracy:** The percentage of correct predictions out of total predictions.
# - **Precision:** The ratio of true positives to the sum of true and false positives.
# - **Recall:** The ratio of true positives to the sum of true positives and false negatives.
# - **F1-Score:** The harmonic mean of precision and recall, providing a single metric for classification performance.
# - **Confusion Matrix:** A matrix showing the true versus predicted class counts, which helps identify where the model is making errors.
#
# ### 7. Performance Visualization
#
# We plotted the training and validation accuracy and loss over the 50 epochs to visually inspect how well the model is learning. Ideally, we expect the loss to decrease and accuracy to increase with each epoch.
#
# In addition, we plotted the confusion matrix to visualize the model’s classification performance across the 10 classes.
#
# ### 8. Optimization Strategies
#
# To further improve the model's performance:
# - **Early Stopping:** Can be used to stop training when the validation performance stops improving, preventing overfitting.
# - **Learning Rate Scheduling:** Gradually decreasing the learning rate during training can lead to smoother convergence.
# - **Weight Initialization:** Proper initialization of weights helps avoid vanishing or exploding gradients, making training more efficient.
#
# ### Conclusion
#
# This project successfully built a neural network to classify CIFAR-10 images. We demonstrated how to preprocess the data, design a neural network architecture, choose appropriate activation functions and optimizers, and evaluate the model’s performance using multiple metrics. Further improvements can be made using advanced optimization strategies like early stopping and learning rate scheduling.
#
# ---
